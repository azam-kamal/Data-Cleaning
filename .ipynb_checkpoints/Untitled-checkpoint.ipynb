# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
#import prince

#df=pd.read_csv("surgical_intruments_pakistan (1).csv")
# print(df.shape,'\n')
# print("*******************************************************************************\n")
# print(df.describe(),"\n")
# print("*******************************************************************************\n")
# print(df.info())
# print("*******************************************************************************\n")
# numeric_cols=df.select_dtypes (include=np.number).columns.tolist()
# df_num=df[numeric_cols]
# print(df_num.columns.tolist())

#Cleaning
#Identifying White Space
#print(df.groupby(['listing-logo href','img-thumbnail src','list-unstyle href']).size(),'/n')

#Average Num of Null Value
#print(df.isna().mean())
#Graph
#df.isna().mean().plot(kind='barh')
#df=df.loc[:,df.isna().mean<.3]

#Replacing Null Values with NaN
#df=df.replace('NA',np.nan)
#df=df.dropna()
#df.info()

#Removing Duplicate rows
#print(df.duplicated().sum())
#df=df.drop_duplicates()
#df.info()

# %%
df=pd.read_csv("surgical_intruments_pakistan (1).csv")
print(df.shape,'\n')
print("*******************************************************************************\n")
#print(df.describe(),"\n")
print(df.head())
print("*******************************************************************************\n")
# Out:
# (234, 33)
#
# *******************************************************************************
#
#                                    listing-logo href  \
# 0  https://www.jamals.com/z-dentamen-instruments-...
# 1                                                NaN
# 2  https://www.jamals.com/talc-industries/361340?...
# 3                                                NaN
# 4  https://www.jamals.com/mehria-group-of-industr...
#
#                                    img-thumbnail src  \
# 0  https://www.jamals.com/images/logo-upload/2229...
# 1                                                NaN
# 2  https://www.jamals.com/images/logo-upload/4846...
# 3                                                NaN
# 4  https://www.jamals.com/images/logo-upload/1042...
#
#                           list-unstyle href  \
# 0  https://twitter.com/uspublishers?lang=en
# 1                                       NaN
# 2  https://twitter.com/uspublishers?lang=en
# ...

# %%
#print(df.describe(),'\n')
#to_drop=['btn','btn 2','control-label 7','text-count','control-label 5','listing_readmore','control-label','control-label 2',
         'control-label 3',]
#df.drop(columns=to_drop, inplace=True)
#print("***********************************************************************\n")
#print(df.describe(),'\n')
# Out:
#                                         listing-logo href  \
# count                                                 108
# unique                                                108
# top     https://www.jamals.com/m.m.-surgical/334705?pr...
# freq                                                    1
#
#                                         img-thumbnail src  \
# count                                                  72
# unique                                                 12
# top     https://www.jamals.com/images/logo-upload/logo...
# freq                                                   61
#
#                                list-unstyle href  \
# count                                        108
# unique                                         2
# top     https://twitter.com/uspublishers?lang=en
# freq                                         107
#
#                                 list-unstyle href 2  \
# count                                           108
# ...

# %%
to_drop2=['close','sr-only','modal-title','listing_readmore href','listing_catalogue','list-unstyle href 4',
'list-unstyle href 3','list-unstyle href 2','list-unstyle href']
df.drop(columns=to_drop2, inplace=True)
print(df.describe())
print("***********************************************************************\n")
# Out:
#                                         listing-logo href  \
# count                                                 108
# unique                                                108
# top     https://www.jamals.com/m.m.-surgical/334705?pr...
# freq                                                    1
#
#                                         img-thumbnail src     add-title  \
# count                                                  72           108
# unique                                                 12           108
# top     https://www.jamals.com/images/logo-upload/logo...  B. ALI IMPEX
# freq                                                   61             1
#
#                             listing-info rating-label contactUser  \
# count                                107          108         108
# unique                               107            1           1
# top     Shah Saydan,P.O.Box:966, Sialkot     0 review     Message
# ...

# %%
print(df.describe())
# Out:
#                                         listing-logo href  \
# count                                                 108
# unique                                                108
# top     https://www.jamals.com/m.m.-surgical/334705?pr...
# freq                                                    1
#
#                                         img-thumbnail src     add-title  \
# count                                                  72           108
# unique                                                 12           108
# top     https://www.jamals.com/images/logo-upload/logo...  B. ALI IMPEX
# freq                                                   61             1
#
#                             listing-info rating-label contactUser  \
# count                                107          108         108
# unique                               107            1           1
# top     Shah Saydan,P.O.Box:966, Sialkot     0 review     Message
# ...

# %%
to_drop3=['rating-label','contactUser']
df.drop(columns=to_drop3, inplace=True)
df.head()
print('*********************\n')
print(df.describe())
# Out:
# *********************
#
#                                         listing-logo href  \
# count                                                 108
# unique                                                108
# top     https://www.jamals.com/m.m.-surgical/334705?pr...
# freq                                                    1
#
#                                         img-thumbnail src     add-title  \
# count                                                  72           108
# unique                                                 12           108
# top     https://www.jamals.com/images/logo-upload/logo...  B. ALI IMPEX
# freq                                                   61             1
#
#                             listing-info  \
# count                                107
# unique                               107
# top     Shah Saydan,P.O.Box:966, Sialkot
# freq                                   1
#
#                                          contactUser href  \
# ...

# %%
df.head()
# Out:
#                                    listing-logo href  \
# 0  https://www.jamals.com/z-dentamen-instruments-...
# 1                                                NaN
# 2  https://www.jamals.com/talc-industries/361340?...
# 3                                                NaN
# 4  https://www.jamals.com/mehria-group-of-industr...
#
#                                    img-thumbnail src  \
# 0  https://www.jamals.com/images/logo-upload/2229...
# 1                                                NaN
# 2  https://www.jamals.com/images/logo-upload/4846...
# 3                                                NaN
# 4  https://www.jamals.com/images/logo-upload/1042...
#
#                         add-title  \
# 0  Z-DENTAMEN INSTRUMENTS COMPANY
# 1                             NaN
# 2                 TALC INDUSTRIES
# 3                             NaN
# 4      MEHRIA GROUP OF INDUSTRIES
#
#                                     listing-info  \
# 0               11-3/B,Model Town,Ugoki, Sialkot
# ...

# %%
#Removing Duplicate rows
print(df.duplicated().sum())
df=df.drop_duplicates()
df.head()
# Out:
# 17
#                                    listing-logo href  \
# 0  https://www.jamals.com/z-dentamen-instruments-...
# 1                                                NaN
# 2  https://www.jamals.com/talc-industries/361340?...
# 3                                                NaN
# 4  https://www.jamals.com/mehria-group-of-industr...
#
#                                    img-thumbnail src  \
# 0  https://www.jamals.com/images/logo-upload/2229...
# 1                                                NaN
# 2  https://www.jamals.com/images/logo-upload/4846...
# 3                                                NaN
# 4  https://www.jamals.com/images/logo-upload/1042...
#
#                         add-title  \
# 0  Z-DENTAMEN INSTRUMENTS COMPANY
# 1                             NaN
# 2                 TALC INDUSTRIES
# 3                             NaN
# 4      MEHRIA GROUP OF INDUSTRIES
#
#                                     listing-info  \
# ...

# %%
print(df.shape,'\n')
print(df.info())
# Out:
# (217, 13)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 217 entries, 0 to 232
# Data columns (total 13 columns):
# listing-logo href       108 non-null object
# img-thumbnail src       72 non-null object
# add-title               108 non-null object
# listing-info            107 non-null object
# contactUser href        108 non-null object
# listing_class           108 non-null object
# listing_class href      108 non-null object
# listing_class 2         70 non-null object
# listing_class href 2    70 non-null object
# listing_class 3         53 non-null object
# listing_class href 3    53 non-null object
# control-label 4         108 non-null object
# g-recaptcha src         108 non-null object
# dtypes: object(13)
# memory usage: 23.7+ KB
# None

# %%
df.to_csv('surgical_intrument.csv')

# %%
df.head()
print("Before Shifting..........................................................\n")
df['control-label 4'] = df['control-label 4'].shift(-1)
df = df.dropna()
df.head()
# Out:
# Before Shifting..........................................................
# C:\Users\Azam\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Empty DataFrame
# Columns: [listing-logo href, img-thumbnail src, add-title, listing-info, contactUser href, listing_class, listing_class href, listing_class 2, listing_class href 2, listing_class 3, listing_class href 3, control-label 4, g-recaptcha src]
# Index: []

# %%
print(df.describe())
# Out:
#        listing-logo href img-thumbnail src add-title listing-info  \
# count                  0                 0         0            0
# unique                 0                 0         0            0
# top                  NaN               NaN       NaN          NaN
# freq                 NaN               NaN       NaN          NaN
#
#        contactUser href listing_class listing_class href listing_class 2  \
# count                 0             0                  0               0
# unique                0             0                  0               0
# top                 NaN           NaN                NaN             NaN
# freq                NaN           NaN                NaN             NaN
#
#        listing_class href 2 listing_class 3 listing_class href 3  \
# count                     0               0                    0
# unique                    0               0                    0
# top                     NaN             NaN                  NaN
# ...

# %%
df.to_csv("last.csv")

# %%
df3=pd.read_csv("surgical_intrument.csv")
df3.head()
# Out:
#    Unnamed: 0                                  listing-logo href  \
# 0           0  https://www.jamals.com/z-dentamen-instruments-...
# 1           1                                                NaN
# 2           2  https://www.jamals.com/talc-industries/361340?...
# 3           3                                                NaN
# 4           4  https://www.jamals.com/mehria-group-of-industr...
#
#                                    img-thumbnail src  \
# 0  https://www.jamals.com/images/logo-upload/2229...
# 1                                                NaN
# 2  https://www.jamals.com/images/logo-upload/4846...
# 3                                                NaN
# 4  https://www.jamals.com/images/logo-upload/1042...
#
#                         add-title  \
# 0  Z-DENTAMEN INSTRUMENTS COMPANY
# 1                             NaN
# 2                 TALC INDUSTRIES
# 3                             NaN
# 4      MEHRIA GROUP OF INDUSTRIES
#
# ...

# %%
df3['control-label 4']=df3['control-label 4'].shift(-1)
df3.head()
# Out:
#    Unnamed: 0                                  listing-logo href  \
# 0           0  https://www.jamals.com/z-dentamen-instruments-...
# 1           1                                                NaN
# 2           2  https://www.jamals.com/talc-industries/361340?...
# 3           3                                                NaN
# 4           4  https://www.jamals.com/mehria-group-of-industr...
#
#                                    img-thumbnail src  \
# 0  https://www.jamals.com/images/logo-upload/2229...
# 1                                                NaN
# 2  https://www.jamals.com/images/logo-upload/4846...
# 3                                                NaN
# 4  https://www.jamals.com/images/logo-upload/1042...
#
#                         add-title  \
# 0  Z-DENTAMEN INSTRUMENTS COMPANY
# 1                             NaN
# 2                 TALC INDUSTRIES
# 3                             NaN
# 4      MEHRIA GROUP OF INDUSTRIES
#
# ...

# %%
df3['g-recaptcha src']=df3['g-recaptcha src'].shift(-1)
df.head()
# Out:
# Empty DataFrame
# Columns: [listing-logo href, img-thumbnail src, add-title, listing-info, contactUser href, listing_class, listing_class href, listing_class 2, listing_class href 2, listing_class 3, listing_class href 3, control-label 4, g-recaptcha src]
# Index: []

# %%
df3.head()
# Out:
#    Unnamed: 0                                  listing-logo href  \
# 0           0  https://www.jamals.com/z-dentamen-instruments-...
# 1           1                                                NaN
# 2           2  https://www.jamals.com/talc-industries/361340?...
# 3           3                                                NaN
# 4           4  https://www.jamals.com/mehria-group-of-industr...
#
#                                    img-thumbnail src  \
# 0  https://www.jamals.com/images/logo-upload/2229...
# 1                                                NaN
# 2  https://www.jamals.com/images/logo-upload/4846...
# 3                                                NaN
# 4  https://www.jamals.com/images/logo-upload/1042...
#
#                         add-title  \
# 0  Z-DENTAMEN INSTRUMENTS COMPANY
# 1                             NaN
# 2                 TALC INDUSTRIES
# 3                             NaN
# 4      MEHRIA GROUP OF INDUSTRIES
#
# ...

# %%
df3.to_csv("Final dataset.csv")

# %%
df4=pd.read_csv('Final dataset.csv')
df4.head()
print("After Dropna func _________________________________________________________\n")
df4.dropna()
df4.head()
# Out:
# After Dropna func _________________________________________________________
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                    listing-logo href  \
# 0  https://www.jamals.com/z-dentamen-instruments-...
# 1                                                NaN
# 2  https://www.jamals.com/talc-industries/361340?...
# 3                                                NaN
# 4  https://www.jamals.com/mehria-group-of-industr...
#
#                                    img-thumbnail src  \
# 0  https://www.jamals.com/images/logo-upload/2229...
# 1                                                NaN
# 2  https://www.jamals.com/images/logo-upload/4846...
# 3                                                NaN
# 4  https://www.jamals.com/images/logo-upload/1042...
#
#                         add-title  \
# ...

# %%
df5=pd.read_csv("Final dataset.csv")
df5.head()
df5.dropna()
df5.head()
# Out:
#                                    listing-logo href  \
# 0  https://www.jamals.com/z-dentamen-instruments-...
# 1                                                NaN
# 2  https://www.jamals.com/talc-industries/361340?...
# 3                                                NaN
# 4  https://www.jamals.com/mehria-group-of-industr...
#
#                                    img-thumbnail src  \
# 0  https://www.jamals.com/images/logo-upload/2229...
# 1                                                NaN
# 2  https://www.jamals.com/images/logo-upload/4846...
# 3                                                NaN
# 4  https://www.jamals.com/images/logo-upload/1042...
#
#                         add-title  \
# 0  Z-DENTAMEN INSTRUMENTS COMPANY
# 1                             NaN
# 2                 TALC INDUSTRIES
# 3                             NaN
# 4      MEHRIA GROUP OF INDUSTRIES
#
#                                     listing-info  \
# 0               11-3/B,Model Town,Ugoki, Sialkot
# ...

# %%
df5.dropna()
# Out:
#                                      listing-logo href  \
# 0    https://www.jamals.com/z-dentamen-instruments-...
# 2    https://www.jamals.com/talc-industries/361340?...
# 4    https://www.jamals.com/mehria-group-of-industr...
# 8    https://www.jamals.com/surgi-valley-pvt-ltd./3...
# 10   https://www.jamals.com/electro-range-manufactu...
# 13   https://www.jamals.com/scientific-instruments-...
# 15   https://www.jamals.com/f.s.t-international/320...
# 17   https://www.jamals.com/azeem-metal-store/36726...
# 19   https://www.jamals.com/j.r.-brothers-surgical-...
# 25   https://www.jamals.com/mughal-international/34...
# 29   https://www.jamals.com/b.-ali-impex/367796?pre...
# 31   https://www.jamals.com/grayrocks-enterprises/3...
# 37   https://www.jamals.com/f.a.-najmmy-industries/...
# 39   https://www.jamals.com/regal-industries/368600...
# 41   https://www.jamals.com/friends-surgico-pvt-ltd...
# 43   https://www.jamals.com/paksmith-surgico/380680...
# ...

# %%
df5.to_csv("Surgical_Intrument_Final.csv")

# %%
print(df5.describe())
# Out:
#                                         listing-logo href  \
# count                                                 108
# unique                                                108
# top     https://www.jamals.com/m.m.-surgical/334705?pr...
# freq                                                    1
#
#                                         img-thumbnail src     add-title  \
# count                                                  72           108
# unique                                                 12           108
# top     https://www.jamals.com/images/logo-upload/logo...  B. ALI IMPEX
# freq                                                   61             1
#
#                             listing-info  \
# count                                107
# unique                               107
# top     Shah Saydan,P.O.Box:966, Sialkot
# freq                                   1
#
#                                          contactUser href  \
# ...

# %%
print(df5.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 13 columns):
# listing-logo href       0 non-null object
# img-thumbnail src       0 non-null object
# add-title               0 non-null object
# listing-info            0 non-null object
# contactUser href        0 non-null object
# listing_class           0 non-null object
# listing_class href      0 non-null object
# listing_class 2         0 non-null object
# listing_class href 2    0 non-null object
# listing_class 3         0 non-null object
# listing_class href 3    0 non-null object
# control-label 4         0 non-null object
# g-recaptcha src         0 non-null object
# dtypes: object(13)
# memory usage: 0.0+ bytes
# None

# %%
df5.head()
# Out:
#                                    listing-logo href  \
# 0  https://www.jamals.com/z-dentamen-instruments-...
# 1                                                NaN
# 2  https://www.jamals.com/talc-industries/361340?...
# 3                                                NaN
# 4  https://www.jamals.com/mehria-group-of-industr...
#
#                                    img-thumbnail src  \
# 0  https://www.jamals.com/images/logo-upload/2229...
# 1                                                NaN
# 2  https://www.jamals.com/images/logo-upload/4846...
# 3                                                NaN
# 4  https://www.jamals.com/images/logo-upload/1042...
#
#                         add-title  \
# 0  Z-DENTAMEN INSTRUMENTS COMPANY
# 1                             NaN
# 2                 TALC INDUSTRIES
# 3                             NaN
# 4      MEHRIA GROUP OF INDUSTRIES
#
#                                     listing-info  \
# 0               11-3/B,Model Town,Ugoki, Sialkot
# ...

# %%
df5.dropna()
# Out:
#                                      listing-logo href  \
# 0    https://www.jamals.com/z-dentamen-instruments-...
# 2    https://www.jamals.com/talc-industries/361340?...
# 4    https://www.jamals.com/mehria-group-of-industr...
# 8    https://www.jamals.com/surgi-valley-pvt-ltd./3...
# 10   https://www.jamals.com/electro-range-manufactu...
# 13   https://www.jamals.com/scientific-instruments-...
# 15   https://www.jamals.com/f.s.t-international/320...
# 17   https://www.jamals.com/azeem-metal-store/36726...
# 19   https://www.jamals.com/j.r.-brothers-surgical-...
# 25   https://www.jamals.com/mughal-international/34...
# 29   https://www.jamals.com/b.-ali-impex/367796?pre...
# 31   https://www.jamals.com/grayrocks-enterprises/3...
# 37   https://www.jamals.com/f.a.-najmmy-industries/...
# 39   https://www.jamals.com/regal-industries/368600...
# 41   https://www.jamals.com/friends-surgico-pvt-ltd...
# 43   https://www.jamals.com/paksmith-surgico/380680...
# ...

# %%
df5=df5.dropna()
df5.head()
# Out:
#                                     listing-logo href  \
# 0   https://www.jamals.com/z-dentamen-instruments-...
# 2   https://www.jamals.com/talc-industries/361340?...
# 4   https://www.jamals.com/mehria-group-of-industr...
# 8   https://www.jamals.com/surgi-valley-pvt-ltd./3...
# 10  https://www.jamals.com/electro-range-manufactu...
#
#                                     img-thumbnail src  \
# 0   https://www.jamals.com/images/logo-upload/2229...
# 2   https://www.jamals.com/images/logo-upload/4846...
# 4   https://www.jamals.com/images/logo-upload/1042...
# 8   https://www.jamals.com/images/logo-upload/1118...
# 10  https://www.jamals.com/images/logo-upload/1123...
#
#                               add-title  \
# 0        Z-DENTAMEN INSTRUMENTS COMPANY
# 2                       TALC INDUSTRIES
# 4            MEHRIA GROUP OF INDUSTRIES
# 8               SURGI VALLEY (PVT) LTD.
# 10  ELECTRO RANGE MANUFACTURING COMPANY
#
#                                          listing-info  \
# ...

# %%
df5.to_csv("Surgical_Intrument_Final.csv")

# %%
df5.drop(df.columns[0], axis=1)
# Out:
#                                      img-thumbnail src  \
# 0    https://www.jamals.com/images/logo-upload/2229...
# 2    https://www.jamals.com/images/logo-upload/4846...
# 4    https://www.jamals.com/images/logo-upload/1042...
# 8    https://www.jamals.com/images/logo-upload/1118...
# 10   https://www.jamals.com/images/logo-upload/1123...
# 13   https://www.jamals.com/images/logo-upload/5029...
# 15   https://www.jamals.com/images/logo-upload/9192...
# 17   https://www.jamals.com/images/logo-upload/6867...
# 19   https://www.jamals.com/images/logo-upload/2012...
# 25   https://www.jamals.com/images/logo-upload/logo...
# 29   https://www.jamals.com/images/logo-upload/7021...
# 31   https://www.jamals.com/images/logo-upload/logo...
# 37   https://www.jamals.com/images/logo-upload/logo...
# 39   https://www.jamals.com/images/logo-upload/logo...
# 41   https://www.jamals.com/images/logo-upload/logo...
# 43   https://www.jamals.com/images/logo-upload/logo...
# ...
